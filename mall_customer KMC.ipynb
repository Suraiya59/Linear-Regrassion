# %% [markdown]
# <a href="https://colab.research.google.com/github/suraiyasumi/Linear-Regrassion/blob/main/mall_customer%20KMC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as splt
import seaborn
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x78a2c2fab4e0>

# %%
from google . colab import files
files.upload()
# Out:
#      <input type="file" id="files-b8ed2c62-421f-457a-9b54-f2e9a590dcf2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8ed2c62-421f-457a-9b54-f2e9a590dcf2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
 df= pd.read_csv('mall customer.csv')

# %%
df
# Out:
#      CustomerID  gender  age  income  score
# 0             1    Male   19      15     39
# 1             2    Male   21      15     81
# 2             3  Female   20      16      6
# 3             4  Female   23      16     77
# 4             5  Female   31      17     40
# ..          ...     ...  ...     ...    ...
# 195         196  Female   35     120     79
# 196         197  Female   45     126     28
# 197         198    Male   32     126     74
# 198         199    Male   32     137     18
# 199         200    Male   30     137     83
#
# [200 rows x 5 columns]

# %%
df.shape
# Out:
# (200, 5)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.describe()
# Out:
#        CustomerID         age      income       score
# count  200.000000  200.000000  200.000000  200.000000
# mean   100.500000   38.850000   60.560000   50.200000
# std     57.879185   13.969007   26.264721   25.823522
# min      1.000000   18.000000   15.000000    1.000000
# 25%     50.750000   28.750000   41.500000   34.750000
# 50%    100.500000   36.000000   61.500000   50.000000
# 75%    150.250000   49.000000   78.000000   73.000000
# max    200.000000   70.000000  137.000000   99.000000

# %%
seaborn.pairplot(df[['age','income','score']])

# %%
import sklearn.cluster as cluster

# %%
kmeans= cluster.KMeans(n_clusters =5)

# %%
kmeans=kmeans .fit(df[['score','income']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
kmeans.cluster_centers_
# Out:
# array([[82.12820513, 86.53846154],
#        [49.51851852, 55.2962963 ],
#        [17.11428571, 88.2       ],
#        [20.91304348, 26.30434783],
#        [79.36363636, 25.72727273]])

# %%
df['income_cluster']= kmeans.labels_

# %%
df
# Out:
#      CustomerID  gender  age  income  score  income_cluster
# 0             1    Male   19      15     39               3
# 1             2    Male   21      15     81               4
# 2             3  Female   20      16      6               3
# 3             4  Female   23      16     77               4
# 4             5  Female   31      17     40               3
# ..          ...     ...  ...     ...    ...             ...
# 195         196  Female   35     120     79               0
# 196         197  Female   45     126     28               2
# 197         198    Male   32     126     74               0
# 198         199    Male   32     137     18               2
# 199         200    Male   30     137     83               0
#
# [200 rows x 6 columns]

# %%
df['income_cluster'].value_counts()
# Out:
# 1    81
# 0    39
# 2    35
# 3    23
# 4    22
# Name: income_cluster, dtype: int64

# %%
Kmeans=cluster.KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[82.12820513, 86.53846154],
#        [49.51851852, 55.2962963 ],
#        [17.11428571, 88.2       ],
#        [20.91304348, 26.30434783],
#        [79.36363636, 25.72727273]])

# %%
seaborn.scatterplot(x='income',y='score',hue= 'income_cluster',data=df)
# Out:
# <Axes: xlabel='score', ylabel='Count'>

# %%
df['age_clusters']= kmeans.labels_

# %%
df['age_clusters']= kmeans.labels_

# %%
df['age_clusters'] .value_counts()
# Out:
# 1    81
# 0    39
# 2    35
# 3    23
# 4    22
# Name: age_clusters, dtype: int64

# %%
df
# Out:
#      CustomerID  gender  age  income  score  income_cluster  age_clusters
# 0             1    Male   19      15     39               3             3
# 1             2    Male   21      15     81               4             4
# 2             3  Female   20      16      6               3             3
# 3             4  Female   23      16     77               4             4
# 4             5  Female   31      17     40               3             3
# ..          ...     ...  ...     ...    ...             ...           ...
# 195         196  Female   35     120     79               0             0
# 196         197  Female   45     126     28               2             2
# 197         198    Male   32     126     74               0             0
# 198         199    Male   32     137     18               2             2
# 199         200    Male   30     137     83               0             0
#
# [200 rows x 7 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# ...
