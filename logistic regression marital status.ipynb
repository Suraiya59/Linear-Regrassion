# %% [markdown]
# <a href="https://colab.research.google.com/github/suraiyasumi/Linear-Regrassion/blob/main/logistic%20regression%20marital%20status.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip install sklearn

# %%
from google. colab import files
files .upload()
# Out:
#      <input type="file" id="files-183cc724-145a-4305-9dc4-db9cdfed6eda" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-183cc724-145a-4305-9dc4-db9cdfed6eda">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('marital status.csv')

# %%
df
# Out:
#     age  status
# 0    21     0.0
# 1    33     1.0
# 2    24     0.0
# 3    28     1.0
# 4    17     0.0
# 5    33     1.0
# 6    23     0.0
# 7    30     0.0
# 8    29     1.0
# 9    22     0.0
# 10   26     1.0
# 11   20     0.0
# 12   22     0.0
# 13   24     NaN
# 14   34     1.0
# 15   29     1.0
# 16   16     0.0
# 17   18     0.0
# 18   26     1.0
# 19   25     1.0

# %%
df.isnull().sum()
# Out:
# age       0
# status    0
# dtype: int64

# %%
handle=df['status'].median()

# %%
handle
# Out:
# 0.0

# %%
df.status=df.status.fillna(handle)

# %%
df
# Out:
#     age  status
# 0    21     0.0
# 1    33     1.0
# 2    24     0.0
# 3    28     1.0
# 4    17     0.0
# 5    33     1.0
# 6    23     0.0
# 7    30     0.0
# 8    29     1.0
# 9    22     0.0
# 10   26     1.0
# 11   20     0.0
# 12   22     0.0
# 13   24     0.0
# 14   34     1.0
# 15   29     1.0
# 16   16     0.0
# 17   18     0.0
# 18   26     1.0
# 19   25     1.0

# %%
df['status'].value_counts()
# Out:
# 0.0    11
# 1.0     9
# Name: status, dtype: int64

# %% [markdown]
# seperate the x,y value

# %%
x=df[['age']]

# %%
y=df[['status']]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=.30,random_state=1)

# %%
xtest
# Out:
#     age
# 3    28
# 16   16
# 6    23
# 10   26
# 2    24
# 14   34

# %%
ytest
# Out:
#     status
# 3      1.0
# 16     0.0
# 6      0.0
# 10     1.0
# 2      0.0
# 14     1.0
